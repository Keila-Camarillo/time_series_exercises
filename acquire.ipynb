# %%
# Imports
import pandas as pd
import requests
import acquire as a

# %%
def get_json(base_url, ext_url=""):
    # Make the API request
    url = base_url + ext_url
    response = requests.get(url)
    data = response.json()
    data = data['results']

    # Create the initial DataFrame
    df = pd.DataFrame(data)

    # Concatenate the initial DataFrame with the extracted data
    df = pd.concat([df, pd.DataFrame(data)])

    # Reset the index of the merged DataFrame
    df = df.reset_index()

    return df

# %% [markdown]
# 1. Using the code from the lesson as a guide and the REST API from https://swapi.dev/ as we did in the lesson, create a dataframe named people that has all of the data for people.

# %%
base_url = "https://swapi.dev/api/"
ext_url = "people/"
people = a.get_json(base_url, ext_url)
people.head()
# Out:
#    index            name height mass hair_color   skin_color eye_color  \
# 0      0  Luke Skywalker    172   77      blond         fair      blue
# 1      1           C-3PO    167   75        n/a         gold    yellow
# 2      2           R2-D2     96   32        n/a  white, blue       red
# 3      3     Darth Vader    202  136       none        white    yellow
# 4      4     Leia Organa    150   49      brown        light     brown
#
#   birth_year  gender                         homeworld  \
# 0      19BBY    male  https://swapi.dev/api/planets/1/
# 1     112BBY     n/a  https://swapi.dev/api/planets/1/
# 2      33BBY     n/a  https://swapi.dev/api/planets/8/
# 3    41.9BBY    male  https://swapi.dev/api/planets/1/
# 4      19BBY  female  https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# ...

# %% [markdown]
# 2. Do the same thing, but for planets.

# %%
ext_url2 = "planets/"
planets = a.get_json(base_url, ext_url2)
planets.head()
# Out:
#    index      name rotation_period orbital_period diameter  \
# 0      0  Tatooine              23            304    10465
# 1      1  Alderaan              24            364    12500
# 2      2  Yavin IV              24           4818    10200
# 3      3      Hoth              23            549     7200
# 4      4   Dagobah              23            341     8900
#
#                climate       gravity                             terrain  \
# 0                 arid    1 standard                              desert
# 1            temperate    1 standard               grasslands, mountains
# 2  temperate, tropical    1 standard                 jungle, rainforests
# 3               frozen  1.1 standard  tundra, ice caves, mountain ranges
# 4                murky           N/A                      swamp, jungles
#
#   surface_water  population  \
# 0             1      200000
# 1            40  2000000000
# 2             8        1000
# 3           100     unknown
# ...

# %% [markdown]
# 3. Extract the data for starships.

# %%
ext_url3 = "starships/"
starships = a.get_json(base_url, ext_url2)
starships.head()
# Out:
#    index      name rotation_period orbital_period diameter  \
# 0      0  Tatooine              23            304    10465
# 1      1  Alderaan              24            364    12500
# 2      2  Yavin IV              24           4818    10200
# 3      3      Hoth              23            549     7200
# 4      4   Dagobah              23            341     8900
#
#                climate       gravity                             terrain  \
# 0                 arid    1 standard                              desert
# 1            temperate    1 standard               grasslands, mountains
# 2  temperate, tropical    1 standard                 jungle, rainforests
# 3               frozen  1.1 standard  tundra, ice caves, mountain ranges
# 4                murky           N/A                      swamp, jungles
#
#   surface_water  population  \
# 0             1      200000
# 1            40  2000000000
# 2             8        1000
# 3           100     unknown
# ...

# %% [markdown]
# 4. Save the data in your files to local csv files so that it will be faster to access in the future.

# %%
people.to_csv('people.csv')

# %%
planets.to_csv('planets.csv')

# %%
starships.to_csv('starships.csv')

# %% [markdown]
# 5. Combine the data from your three separate dataframes into one large dataframe.

# %%
# seperates lists in columns
people = people.explode('starships')
# Merge df1 and df2 based on a common column
merged_df = pd.merge(people, planets, left_on='homeworld', right_on='url')

merged_df.head()
# Out:
#    index_x          name_x height mass hair_color skin_color eye_color  \
# 0        0  Luke Skywalker    172   77      blond       fair      blue
# 1        0  Luke Skywalker    172   77      blond       fair      blue
# 2        0  Luke Skywalker    172   77      blond       fair      blue
# 3        0  Luke Skywalker    172   77      blond       fair      blue
# 4        1           C-3PO    167   75        n/a       gold    yellow
#
#   birth_year gender                         homeworld  ... climate  \
# 0      19BBY   male  https://swapi.dev/api/planets/1/  ...    arid
# 1      19BBY   male  https://swapi.dev/api/planets/1/  ...    arid
# 2      19BBY   male  https://swapi.dev/api/planets/1/  ...    arid
# 3      19BBY   male  https://swapi.dev/api/planets/1/  ...    arid
# 4     112BBY    n/a  https://swapi.dev/api/planets/1/  ...    arid
#
#       gravity terrain surface_water population  \
# 0  1 standard  desert             1     200000
# ...

# %%
final_df = pd.merge(merged_df, starships, left_on='starships', right_on='url')
final_df
# Out:
# Empty DataFrame
# Columns: [index_x, name_x, height, mass, hair_color, skin_color, eye_color, birth_year, gender, homeworld, films_x, species, vehicles, starships, created_x, edited_x, url_x, index_y, name_y, rotation_period_x, orbital_period_x, diameter_x, climate_x, gravity_x, terrain_x, surface_water_x, population_x, residents_x, films_y, created_y, edited_y, url_y, index, name, rotation_period_y, orbital_period_y, diameter_y, climate_y, gravity_y, terrain_y, surface_water_y, population_y, residents_y, films, created, edited, url]
# Index: []
#
# [0 rows x 47 columns]

# %% [markdown]
# 6. Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv

# %%
opsd_data = a.acquire_opsd_data(url)
opsd_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/bf/lhpb5n_j1xj4msxy6nrm9h7h0000gn/T/ipykernel_20944/2362242408.py in <module>
# ----> 1 opsd_data = a.acquire_opsd_data(url)
#       2 opsd_data
#
# NameError: name 'url' is not defined
